# %%
import pandas as pd
import numpy as np

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Вам дан датасэт с 2-мя фичами (колонками). Постройте график распределения точек (наблюдений) в пространстве этих 2-ух переменных 
#(одна из них будет x, а другая - y) и напишите число кластеров, формируемых наблюдениями.
#В ответе вы должны указать число кластеров в виде числа (например: 3).
data = pd.read_csv('C:/Users/oxyge/Desktop/OneDrive/My_activity/Programs/python/python_intro_ds_ml/1_07_visualisation/dataset_209770_6.txt', sep=' ')

# %%
data
# Out:
#               x            y
# 0   1397.928334   292.757034
# 1    486.063177  1093.901605
# 2    997.588715   592.949096
# 3    687.842455  1004.938408
# 4   1305.150852   895.179198
# 5   1517.939702   798.292767
# 6   1295.081249   890.009283
# 7   1005.736257   599.681473
# 8    494.832380  1105.383820
# 9    521.191799  1096.699344
# 10   699.077640  1007.520783
# 11  1401.983552   312.524691
# 12  1298.676096   905.337259
# 13  1412.088040   293.805838
# 14   682.642713  1009.204100
# 15  1499.182172   792.647991
# 16   689.333617   993.119639
# 17  1411.968567   293.928520
# 18   495.954264  1105.706765
# 19  1302.229452   898.117689
# 20  1489.824341   790.817411
# 21  1502.067253   795.582838
# 22  1396.603236   288.104052
# 23  1314.419928   904.518471
# 24  1403.446259   299.304031
# 25  1488.438430   799.718859
# 26   999.616626   582.242849
# 27  1506.061215   792.683718
# 28   491.917582  1099.650140
# 29  1514.188893   798.751012
# 30  1406.694265   290.782543
# ...

# %%
sns.lmplot(x='x', y='y', fit_reg=False,data=data)
